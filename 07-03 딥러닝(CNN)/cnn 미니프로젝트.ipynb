# %%
# !git clone https://github.com/Lilcob/dataset_for_lg.git
# Out:
# Cloning into 'dataset_for_lg'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 977.77 KiB | 4.14 MiB/s, done.

# %%
# !unzip './dataset_for_lg/dataset_lg.zip'
# Out:
# Archive:  ./dataset_for_lg/dataset_lg.zip
#    creating: dataset/
#   inflating: __MACOSX/._dataset
#    creating: dataset/lung/
#    creating: dataset/lung_cancer/
#   inflating: dataset/lung/06-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/005X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/007-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/009-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/002.png
#   inflating: dataset/lung/10-sh_lung_ct.jpeg
#   inflating: dataset/lung/09-sh_lung_ct.jpeg
#   inflating: dataset/lung/12-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/07-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/15-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/01-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/06-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/06-sh_lung_ct.jpeg
#   inflating: dataset/lung/006-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/07-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/03-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/17-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/006-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/008-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/002-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/001X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/004-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/016X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/08-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/009X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/01-sh_lung_ct.jpeg
#   inflating: dataset/lung/15-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/014-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/10-sanha_lung.jpeg
#   inflating: dataset/lung/01-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/09-sanha_lung.jpeg
#   inflating: dataset/lung/15-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/010-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/005-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/12-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/14-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/001-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/015X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/07-sanha_lung.jpeg
#   inflating: dataset/lung/10-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/11-sanha_lung.jpeg
#   inflating: dataset/lung/12-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/13-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/15-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/011-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/05-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/07-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/011X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/14-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/13-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/07-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/015-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/16-sh_lung_ct.jpeg
#   inflating: dataset/lung/08-sanha_lung.jpeg
#   inflating: dataset/lung/11-sh_lung_ct.jpeg
#   inflating: dataset/lung/002-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/006X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/02-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/08-sh_lung_ct.jpeg
#   inflating: dataset/lung/16-sanha_lung.jpeg
#   inflating: dataset/lung/003-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/07-sh_lung_ct.jpeg
#   inflating: dataset/lung/007-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/003-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/11-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/05-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/05-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/02-sh_lung_ct.jpeg
#   inflating: dataset/lung/03-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/04-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/09-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/17-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/013-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/16-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/05-sanha_lung.jpeg
#   inflating: dataset/lung/11-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/015-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/02-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/013X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/04-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/014-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/08-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/03-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/02-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/14-sh_lung_ct.jpeg
#   inflating: dataset/lung/06-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/12-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/08-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/008X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/13-sanha_lung.jpeg
#   inflating: dataset/lung/005-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/14-sanha_lung.jpeg
#   inflating: dataset/lung/13-sh_lung_ct.jpeg
#   inflating: dataset/lung/04-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/001-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/016-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/004X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/02-sanha_lung.jpeg
#   inflating: dataset/lung/11-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/04-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/10-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/05-sh_lung_ct.jpeg
#   inflating: dataset/lung/009-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/11-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/15-sanha_lung.jpeg
#   inflating: dataset/lung/17-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/03-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/10-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/14-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/003X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/013-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/004-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/08-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/16-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/12-sh_lung_ct.jpeg
#   inflating: dataset/lung/05-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/01-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/10-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/008-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/16-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/02-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/16-ksj_A collection of normal lung x-ray pictures.jpeg
#   inflating: dataset/lung/007X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/012-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/09-hsk lung cancer side view.jpeg
#   inflating: dataset/lung/04-sh_lung_ct.jpeg
#   inflating: dataset/lung/09-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/03-sh_lung_ct.jpeg
#   inflating: dataset/lung/012-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/04-sanha_lung.jpeg
#   inflating: dataset/lung/010-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/010X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/06-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/016-LSJ_normal chest pa.jpeg
#   inflating: dataset/lung/15-sh_lung_ct.jpeg
#   inflating: dataset/lung/14-ksj_Representative picture of healthy lung x-ray.jpeg
#   inflating: dataset/lung/13-LSJ_nomal lung x ray.jpeg
#   inflating: dataset/lung/011-LSJ_radiografi�?a de pulmo�?n normal.jpeg
#   inflating: dataset/lung/014X-ray of severe lung disease.jpeg
#   inflating: dataset/lung/12-sanha_lung.jpeg
#   inflating: dataset/lung_cancer/007-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/004-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/008-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/09-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/003-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/008-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/06-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/009-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/010-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/006-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/007-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/008- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/009- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/.DS_Store
#   inflating: __MACOSX/dataset/lung_cancer/._.DS_Store
#   inflating: dataset/lung_cancer/003-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/009-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/003-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/07-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/08-LSJ_lung cancer xray images.jpeg
#   inflating: dataset/lung_cancer/010-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/004-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/010- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/007-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/006-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/01-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/03-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/06-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/07-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/004-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/001-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/002-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/10-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/005-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/05-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/002-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/01-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/010-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/004-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/07-LSJ_lung cancer xray images.jpeg
#   inflating: dataset/lung_cancer/008-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/002-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/002-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/06-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/04-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/09-LSJ_lung cancer xray images.jpeg
#   inflating: dataset/lung_cancer/010-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/009-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/07-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/02-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/006-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/08-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/002-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/04-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/04-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/001-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/08-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/03-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/006- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/02-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/007- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/001-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/004- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/009-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/005- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/009-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/003- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/005-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/002- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/01-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/001- hsk lung cancer ct scan stage1 .jpeg
#   inflating: dataset/lung_cancer/006-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/004-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/006-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/02-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/03-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/10-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/005-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/05-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/005-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/09-hsk lung cancer side view.jpeg
#   inflating: dataset/lung_cancer/007-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/001-IJH_Lunge ro�?ntgen.jpeg
#   inflating: dataset/lung_cancer/003-ksj_lung cancer x-ray Photo collection[jpg]-.jpg
#   inflating: dataset/lung_cancer/005-IJH_cancer_chest_x_ray.jpeg
#   inflating: dataset/lung_cancer/008-LJH_lung_x-ray_hd_sample.jpeg
#   inflating: dataset/lung_cancer/003-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/05-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/09-hsk_lungcancer_stage4.jpeg
#   inflating: dataset/lung_cancer/08-LSJ_lung cancer on an chest x ray.jpeg
#   inflating: dataset/lung_cancer/010-LSJ_lung cancer end stage xray.jpeg
#   inflating: dataset/lung_cancer/001-ksj_lung cancer x-ray Photo collection[jpg]-.jpg

# %%
dataset_path = './dataset'

# %% [markdown]
# ## 데이터 전처리

# %%
import os
import glob
#pillow 와 opencv가 이미지 라이브러리 처리에 양대산맥
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split

dataset = []
labels = []

folder_name = ['lung','lung_cancer']
for idx,folder in enumerate(folder_name):
    img_dir_name = os.path.join(dataset_path,folder)
    files = glob.glob(img_dir_name + '/*')
    # print(files)
    for file in files:
        img = Image.open(file)
        # print(img) # 모두 이미지의 파일의 크기가 다를 것 
        # 흑백이면 depth가 1, RGB는 3이기때문에 모두 3으로 맞추기
        img = img.convert('RGB')
        #사이즈 동일하게 변경
        img = img.resize((64,64))
        data = np.asarray(img)
        dataset.append(data)
        #라벨 저장, idx lung 폴더는 0, lung_cancer 1
        labels.append(idx)


print(type(data))
print(data.size)
# print(dataset[0], labels[0])

#리스트형태를 Numpy 형태로 바꿀것
datasets = np.array(dataset)
labels = np.array(labels)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 6
#       4 from PIL import Image
#       5 import numpy as np
# ----> 6 from sklearn.model_selection import train_test_split
#       8 dataset = []
#       9 labels = []
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
x_train, x_test, y_train, y_test = train_test_split(datasets,labels,test_size=0.1)
print(x_train.shape)
print(y_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 x_train, x_test, y_train, y_test = train_test_split(datasets,labels,test_size=0.1)
#       2 print(x_train.shape)
#       3 print(y_train.shape)
#
# NameError: name 'train_test_split' is not defined
