# %%
import numpy as np 
import tensorflow as tf

data = np.random.sample((100,2))
labels = np.random.sample((100,1))

dataset = tf.data.Dataset.from_tensor_slices((data,labels))
#데이터를 32개의 배치로 나눔 
dataset = dataset.batch(32)
dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 2), dtype=tf.float64, name=None), TensorSpec(shape=(None, 1), dtype=tf.float64, name=None))>

# %%
#input layer: input 2
#hidden layer 1번: input 2, output 10
#hidden layer 2번: input 10, output 10
#output layer: output 1

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(10,input_dim = 2, activation = 'sigmoid'))
model.add(tf.keras.layers.Dense(10,activation = 'sigmoid'))
model.add(tf.keras.layers.Dense(1,activation = 'sigmoid'))

# %%
model.compile(optimizer ='SGD',loss = 'mse')
model.fit(dataset, epochs = 100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 7ms/step - loss: 0.0859
# Epoch 2/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0858
# Epoch 3/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 4/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0855
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0854
# Epoch 6/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0854
# Epoch 7/100
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0853
# Epoch 8/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0852
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0851
# Epoch 10/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0850
# Epoch 11/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0849
# Epoch 12/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0849
# ...

# %%
model.summary()
# param # 30:  w1,w2와 bias 3개, 노드 10개 ; 30개 
# param # 30:
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 10)                30
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
