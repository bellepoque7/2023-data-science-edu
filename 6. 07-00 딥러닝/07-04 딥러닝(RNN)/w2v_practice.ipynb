# %%
import urllib.request # 파일 다운로드 라이브러리
import zipfile 
from lxml import etree
from nltk.tokenize import word_tokenize, sent_tokenize
import re # 정규표현식 
import nltk # 자연어 처리 전처리 도구

# %%
# nltk.download('punkt')

# %%
# 데이터 다운로드
# urllib.request.urlretrieve("https://raw.githubusercontent.com/ukairia777/tensorflow-nlp-tutorial/main/09.%20Word%20Embedding/dataset/ted_en-20160408.xml", filename="ted_en-20160408.xml")

# %% [markdown]
# 밑에 xml 파일이 너무 큰듯함.

# %%
targetXML = open('ted_en-20160408 copy.xml', 'r', encoding='UTF8')
target_text = etree.parse(targetXML)
# Out:
# Traceback (most recent call last):
#
#   File ~/Library/Python/3.10/lib/python/site-packages/IPython/core/interactiveshell.py:3442 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 2
#     target_text = etree.parse(targetXML)
#
#   File src/lxml/etree.pyx:3541 in lxml.etree.parse
#
#   File src/lxml/parser.pxi:1900 in lxml.etree._parseDocument
#
#   File src/lxml/parser.pxi:1920 in lxml.etree._parseFilelikeDocument
#
#   File src/lxml/parser.pxi:1814 in lxml.etree._parseDocFromFilelike
#
#   File src/lxml/parser.pxi:1204 in lxml.etree._BaseParser._parseDocFromFilelike
#
#   File src/lxml/parser.pxi:618 in lxml.etree._ParserContext._handleParseResultDoc
#
#   File src/lxml/parser.pxi:728 in lxml.etree._handleParseResult
#
#   File src/lxml/parser.pxi:657 in lxml.etree._raiseParseError
#
#   File ~/Documents/GitHub/2023-data-science-edu/6. 07-00 딥러닝/07-04 딥러닝(RNN)/ted_en-20160408 copy.xml:26497
#     </file>
#           ^
# ...

# %%
parse_text = '\n'.join(target_text.xpath('//content/text()'))

# %%
parse_text

# %%
# xml 파일로부터 <content>와 </content> 사이의 내용만 가져온다.
parse_text = '\n'.join(target_text.xpath('//content/text()'))

# 정규 표현식의 sub 모듈을 통해 content 중간에 등장하는 (Audio), (Laughter) 등의 배경음 부분을 제거.
# 해당 코드는 괄호로 구성된 내용을 제거.
content_text = re.sub(r'\([^)]*\)', '', parse_text)

# 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
sent_text = sent_tokenize(content_text)

# 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
normalized_text = []
for string in sent_text:
     tokens = re.sub(r"[^a-z0-9]+", " ", string.lower())
     normalized_text.append(tokens)

# 각 문장에 대해서 NLTK를 이용하여 단어 토큰화를 수행.
result = [word_tokenize(sentence) for sentence in normalized_text]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-672b68f56556> in <module>
#       7
#       8 # 입력 코퍼스에 대해서 NLTK를 이용하여 문장 토큰화를 수행.
# ----> 9 sent_text = sent_tokenize(content_text)
#      10
#      11 # 각 문장에 대해서 구두점을 제거하고, 대문자를 소문자로 변환.
#
# /usr/local/lib/python3.9/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /usr/local/lib/python3.9/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1274         Given a text, returns a list of the sentences in that text.
#    1275         """
# -> 1276         return list(self.sentences_from_text(text, realign_boundaries))
#    1277
#    1278     def debug_decisions(self, text):
#
# ...

# %%
result[:10]

# %%
from gensim.models import Word2Vec, KeyedVectors

model = Word2Vec(sentences=result, size = 100, window = 5,
                 min_count = 2, workers=4, sg=0)
#sentence = 학습할 말뭉치 셋 
#size = 학습완료후 생성된 w2v 차원의 크기
#window = 주변의 단어 몇개 까지 사용 할지
#min_count = 최소한의 등장 단어 턱걸이
#worker = 컴퓨터 자원을 얼마나 사용할지
# sg , 0 = CBOW(적은데이터 유리) ,1 = Skip-gram(데이터가 많을때 강력한 성능)

# %%
model_result = model.most_similar('lady')
print(model_result)
